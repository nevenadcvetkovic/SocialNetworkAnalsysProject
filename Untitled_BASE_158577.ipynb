# %% [markdown]
# # Projekat iz predmeta analiza socijalnih mreza
#
#
# ## Kvantitativna i kvalitativna Analiza stanja profesionalnog muškog tenisa u periodu od 2018. do 2020. godine
#
#
# Ucitavanje podataka

# %%
import pandas as pd

dataPath = "data/atp_matches_2018.csv"

players_dataPath = "data/atp_players.csv"

player_atp_rankings_dataPath = "data/atp_rankings_10s.csv"

data = pd.read_csv(dataPath) 
#print(data.columns)
data.isna().any()

#players
players_data = pd.read_csv(players_dataPath)
#print(players_data)

#atp ranking
players_atp_rank_data = pd.read_csv(player_atp_rankings_dataPath)
players_atp_rank_data.isna().any()
#points null moze biti
#print(players_atp_rank_data)
# Out:
# ranking_date    False
# rank            False
# player          False
# points           True
# dtype: bool

# %%
#provera da li je match_num kolona koja moze da bude uzeta za id

print(data['match_num'].isnull().values.any())
print(data['match_num'].is_unique)
# Out:
# False
# False

# %%
#dodati automatski generisani id kao dodatnu kolonu
data['id'] = data.index
print(data)

#sacuvati u novi fajl
import pickle

with open("data/data2018_cleaned.csv", 'wb') as file:
    pickle.dump(data, file)
# Out:
#                           tourney_id                tourney_name surface  \
# 0                          2018-M020                    Brisbane    Hard
# 1                          2018-M020                    Brisbane    Hard
# 2                          2018-M020                    Brisbane    Hard
# 3                          2018-M020                    Brisbane    Hard
# 4                          2018-M020                    Brisbane    Hard
# ...                              ...                         ...     ...
# 2884                       2018-0605                 Tour Finals    Hard
# 2885                       2018-0605                 Tour Finals    Hard
# 2886  2018-M-DC-2018-WG-M-FRA-CRO-01  Davis Cup WG F: FRA vs CRO    Clay
# 2887  2018-M-DC-2018-WG-M-FRA-CRO-01  Davis Cup WG F: FRA vs CRO    Clay
# 2888  2018-M-DC-2018-WG-M-FRA-CRO-01  Davis Cup WG F: FRA vs CRO    Clay
#
#       draw_size tourney_level  tourney_date  match_num  winner_id  \
# 0            32             A      20180101        271     105992
# 1            32             A      20180101        272     111577
# 2            32             A      20180101        273     104797
# 3            32             A      20180101        275     200282
# 4            32             A      20180101        276     111581
# ...         ...           ...           ...        ...        ...
# 2884          8             F      20181112        299     104925
# 2885          8             F      20181112        300     100644
# 2886          4             D      20181123          1     106432
# 2887          4             D      20181123          2     105227
# 2888          4             D      20181123          4     105227
#
#       winner_seed winner_entry  ... l_1stWon l_2ndWon  l_SvGms l_bpSaved  \
# 0             NaN          NaN  ...     33.0     19.0     14.0       1.0
# 1             NaN          NaN  ...     25.0      7.0      9.0       7.0
# 2             NaN          NaN  ...     37.0     29.0     15.0      10.0
# 3             NaN           WC  ...     33.0     17.0     11.0       4.0
# 4             NaN            Q  ...     28.0      5.0      9.0       0.0
# ...           ...          ...  ...      ...      ...      ...       ...
# 2884          1.0          NaN  ...     23.0      7.0      8.0       5.0
# 2885          3.0          NaN  ...     25.0      8.0     10.0       2.0
# 2886          NaN          NaN  ...     43.0     18.0     15.0       9.0
# 2887          NaN          NaN  ...     39.0     18.0     15.0       1.0
# 2888          NaN          NaN  ...     43.0     21.0     15.0       9.0
#
#       l_bpFaced  winner_rank  winner_rank_points loser_rank loser_rank_points  \
# 0           4.0         47.0              1010.0       52.0             909.0
# 1          11.0         54.0               890.0       94.0             593.0
# 2          16.0         63.0               809.0       30.0            1391.0
# 3           6.0        208.0               245.0       44.0            1055.0
# 4           2.0        175.0               299.0       68.0             755.0
# ...         ...          ...                 ...        ...               ...
# 2884        9.0          1.0              8045.0        6.0            4310.0
# 2885        6.0          5.0              5085.0        1.0            8045.0
# 2886       13.0         12.0              2480.0       40.0            1050.0
# 2887        4.0          7.0              4250.0      259.0             200.0
# 2888       12.0          7.0              4250.0       32.0            1245.0
#
#         id
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 2884  2884
# 2885  2885
# 2886  2886
# 2887  2887
# 2888  2888
#
# [2889 rows x 50 columns]

# %%
import numpy as np

# Selekcija samo kolona 'match_num' i 'id' i grupisanje po match_num
data_grupisano = data[['match_num', 'id']].groupby('match_num')

# agg() radi agregaciju, u ovom slučaju po broju elemenata u grupi
data_agregirano = data_grupisano['id'].agg(np.size)
print(type(data_agregirano))
print(data_agregirano)
# Out:
# <class 'pandas.core.series.Series'>
# match_num
# 1      67
# 2      67
# 4      67
# 5      35
# 100     3
#        ..
# 503     1
# 504     1
# 601     1
# 602     1
# 701     1
# Name: id, Length: 233, dtype: int64

# %%
data_nonunique = data_agregirano[data_agregirano>1]
print(data_nonunique)
# Out:
# match_num
# 1      67
# 2      67
# 4      67
# 5      35
# 100     3
#        ..
# 296    64
# 297    64
# 298    64
# 299    64
# 300    64
# Name: id, Length: 200, dtype: int64

# %%
#naci max i index max broja ponovljenih
trazeni = data_nonunique[data_nonunique == data_nonunique.max()]
print(trazeni)
target_match_num = trazeni.keys()[0]
print(target_match_num)
# Out:
# match_num
# 1    67
# 2    67
# 4    67
# Name: id, dtype: int64
# 1

# %%
#ispisati sve meceve kao match_num imaju odredjeni max
data_target = data[data['match_num'] == target_match_num]
lista_labela = ['tourney_name', 'winner_id', 'loser_id', 'winner_rank', 'loser_rank']
print(data_target[lista_labela])

#ispisi sve ciji je ili winner_rank null ili loser_rank null
data_winOrlos_is_null = data_target[(data_target['winner_rank'].isnull()) | (data_target['loser_rank'].isnull())]
print(data_winOrlos_is_null)

#istraga o igracima ciji je winner_rank u tabeli matches_2018 null ili loser_rank u tabeli matches_2018 null
print(players_data[0].equals(data_winOrlos_is_null['winner_id']))
players_info_rang_null = players_data.loc[(players_data[0].isin(data_winOrlos_is_null['winner_id'])) | (players_data[0].isin(data_winOrlos_is_null['loser_id']))]
print(players_data.loc[(players_data[0].isin(data_winOrlos_is_null['winner_id'])) | (players_data[0].isin(data_winOrlos_is_null['loser_id']))])

#postoje neki koji uopste nemaju upisanu ruku i datum rodjenja, datum rodjenja format double iako u opisu drugaciji format
# Out:
#                      tourney_name  winner_id  loser_id  winner_rank  \
# 266   Davis Cup G1 R1: AUT vs BLR     105589    125802         98.0
# 270   Davis Cup G1 R1: CHI vs ECU     111797    105111         95.0
# 273   Davis Cup G1 R1: CHN vs NZL     104907    105842        308.0
# 276   Davis Cup G1 R1: COL vs BAR     123755    104656        292.0
# 279   Davis Cup G1 R1: DOM vs BRA     105497    106252        284.0
# ...                           ...        ...       ...          ...
# 2425  Davis Cup WG SF: FRA vs ESP     105332    105807         54.0
# 2429  Davis Cup G2 R3: ROU vs POL     105657    111794         81.0
# 2433  Davis Cup G2 R3: THA vs LBN     200273    106397        643.0
# 2437  Davis Cup G2 R3: URU vs MEX     104655    106250         68.0
# 2886   Davis Cup WG F: FRA vs CRO     106432    104871         12.0
#
#       loser_rank
# 266        190.0
# 270        597.0
# 273        253.0
# 276          NaN
# 279        365.0
# ...          ...
# 2425        21.0
# 2429       187.0
# 2433       453.0
# 2437       762.0
# 2886        40.0
#
# [67 rows x 5 columns]
#                              tourney_id                 tourney_name surface  \
# 276   2018-M-DC-2018-G1-AM-M-COL-BAR-01  Davis Cup G1 R1: COL vs BAR    Hard
# 283   2018-M-DC-2018-G1-AO-M-KOR-PAK-01  Davis Cup G1 R1: KOR vs PAK   Grass
# 327   2018-M-DC-2018-G2-AM-M-ESA-URU-01  Davis Cup G2 R1: ESA vs URU    Hard
# 348   2018-M-DC-2018-G2-AO-M-PHI-INA-01  Davis Cup G2 R1: PHI vs INA    Hard
# 352   2018-M-DC-2018-G2-AM-M-PUR-MEX-01  Davis Cup G2 R1: PUR vs MEX    Hard
# 356  2018-M-DC-2018-G2-EPA-M-ROU-LUX-01  Davis Cup G2 R1: ROU vs LUX    Hard
# 934   2018-M-DC-2018-G1-AO-M-PAK-UZB-01  Davis Cup G1 R2: PAK vs UZB   Grass
#
#      draw_size tourney_level  tourney_date  match_num  winner_id  winner_seed  \
# 276          4             D      20180202          1     123755          NaN
# 283          4             D      20180202          1     103529          NaN
# 327          4             D      20180203          1     104655          NaN
# 348          4             D      20180203          1     202165          NaN
# 352          4             D      20180203          1     105688          NaN
# 356          4             D      20180203          1     111167          NaN
# 934          4             D      20180406          1     104797          NaN
#
#     winner_entry  ... l_1stWon l_2ndWon  l_SvGms l_bpSaved  l_bpFaced  \
# 276          NaN  ...     14.0     10.0      8.0       1.0        5.0
# 283          NaN  ...     35.0     22.0     14.0       0.0        2.0
# 327          NaN  ...     26.0      8.0      8.0       4.0        8.0
# 348          NaN  ...     25.0      4.0      8.0       2.0        6.0
# 352          NaN  ...     35.0      8.0     11.0       3.0        7.0
# 356          NaN  ...     41.0     18.0     14.0       3.0        5.0
# 934          NaN  ...     31.0     12.0      8.0       0.0        1.0
#
#      winner_rank  winner_rank_points loser_rank loser_rank_points   id
# 276        292.0               168.0        NaN               NaN  276
# 283          NaN                 NaN      178.0             301.0  283
# 327         32.0              1380.0        NaN               NaN  327
# 348       1371.0                 3.0        NaN               NaN  348
# 352        560.0                54.0        NaN               NaN  352
# 356          NaN                 NaN      596.0              48.0  356
# 934         83.0               673.0        NaN               NaN  934
#
# [7 rows x 50 columns]
# False
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []

# %%
#players_info_rang_null 
#players_atp_rank_data
columns_name_players_atp_rank = ['ranking_date', 'rank', 'player', 'points']
print(players_atp_rank_data[columns_name_players_atp_rank])
print(players_atp_rank_data[columns_name_players_atp_rank].groupby('player').mean())
# Out:
#         ranking_date  rank  player   points
# 0           20100104     1  103819  10550.0
# 1           20100104     2  104745   9205.0
# 2           20100104     3  104925   8310.0
# 3           20100104     4  104918   7030.0
# 4           20100104     5  105223   6785.0
# ...              ...   ...     ...      ...
# 916291      20191230  1922  134833      1.0
# 916292      20191230  1922  144856      1.0
# 916293      20191230  1922  202326      1.0
# 916294      20191230  1926  207307      1.0
# 916295      20191230  1927  208186      1.0
#
# [916296 rows x 4 columns]
#         ranking_date         rank       points
# player
# 100644  2.015885e+07   247.552326  2102.796512
# 101389  2.014282e+07  1724.404255     1.000000
# 101397  2.011134e+07  1204.478261     3.000000
# 101404  2.011255e+07  1031.626374     6.571429
# 101549  2.010697e+07  1468.750000     1.000000
# ...              ...          ...          ...
# 209397  2.019123e+07  1581.000000     1.000000
# 209398  2.019122e+07  1581.666667     1.000000
# 209399  2.019122e+07  1725.666667     1.000000
# 209506  2.018140e+07   940.871212          NaN
# 209508  2.015536e+07  1873.288889     1.000000
#
# [6180 rows x 3 columns]

# %%
import networkx as nx

list_winner = set(data['winner_id'].apply(str).unique())
print(list_winner)
list_loser = set(data['loser_id'].apply(str).unique())
print(list_loser)

skup_id = list_winner.union(list_loser)
print(f"Postoji { len(skup_id) } različitih igrača") # formatiranje ispisa pomoću fstringa

print(data.columns)
# Out:
# {'126774', '105899', '120424', '106410', '105815', '132283', '122669', '105292', '103333', '104198', '104312', '200325', '144817', '105539', '104907', '105561', '127143', '105967', '200460', '104898', '105413', '144750', '106000', '106378', '104926', '105341', '105065', '105948', '106099', '105051', '106401', '104655', '104665', '120792', '106252', '105385', '103781', '105819', '104467', '123921', '200282', '111200', '134770', '105436', '104871', '105497', '111511', '106005', '106043', '111797', '106109', '106148', '104545', '200436', '105812', '144895', '105227', '124116', '109054', '105359', '105657', '133975', '105015', '104269', '111761', '202210', '104534', '105550', '106328', '133430', '103852', '126502', '122078', '110602', '105732', '105238', '104719', '200273', '106233', '105585', '200095', '106432', '111167', '111460', '104607', '106186', '105349', '100644', '105992', '105870', '106175', '106218', '106216', '124187', '105554', '106110', '126530', '105487', '104297', '104919', '105676', '104882', '208029', '126205', '104233', '109739', '126613', '106283', '105062', '106361', '111202', '103529', '105357', '105074', '105064', '106249', '106105', '123755', '105376', '106120', '105041', '105138', '105063', '106065', '104122', '105132', '104022', '103819', '144719', '200075', '105155', '104925', '138846', '106058', '124014', '106329', '106078', '104755', '104542', '105643', '106045', '105499', '134886', '200005', '103499', '105747', '105526', '207415', '126174', '105656', '104571', '106044', '105633', '207139', '106423', '202358', '104291', '105589', '105936', '104586', '106121', '126535', '104999', '105430', '105449', '126526', '105827', '104547', '105882', '106021', '106177', '106214', '111577', '126610', '104797', '122548', '111513', '106281', '111575', '104897', '105806', '208028', '200615', '104180', '126094', '103917', '104252', '104918', '105166', '105807', '111794', '105477', '105634', '138845', '125802', '136440', '126204', '104792', '105578', '106353', '106072', '126652', '104745', '105332', '103607', '106250', '105053', '106415', '103565', '111581', '103970', '106397', '144707', '104672', '104527', '126207', '105577', '104259', '126523', '105916', '106026', '105217', '104629', '111456', '126203', '105023', '128034', '105173', '105432', '104620', '105373', '105614', '105311', '106210', '200000', '106075', '126939', '133297', '122330', '105688', '127300', '134217', '111815', '127570', '111442', '105935', '104251', '104494', '200484', '144760', '105583', '106071', '126190', '104678', '105626', '202165', '105208', '106298', '105216', '103898', '103893', '104660', '106368', '105575', '106150', '106421', '105933', '105777', '105902', '111197', '105671', '134868', '105932', '104468', '104731', '124126', '200059', '105453', '105683', '105379', '105077', '105223'}
# {'105899', '207421', '104198', '105960', '105539', '200031', '200460', '105413', '105341', '106378', '105065', '104665', '104655', '106252', '105385', '200282', '134770', '106198', '104545', '200436', '105227', '105359', '104269', '126127', '126120', '124079', '133430', '104719', '105238', '106233', '111167', '105349', '100644', '105515', '106218', '106175', '106216', '105649', '106110', '111795', '144807', '103529', '106249', '207973', '105041', '200620', '105132', '104460', '206768', '138846', '124014', '104542', '200624', '106232', '200401', '103499', '106348', '104586', '105587', '105449', '126526', '106214', '105566', '206642', '105806', '104810', '206000', '104252', '104918', '111794', '105634', '104932', '136440', '106072', '103607', '105053', '106397', '138431', '104672', '200384', '104494', '104563', '105216', '106150', '111197', '105777', '105671', '134868', '200059', '105493', '106426', '200278', '132283', '105606', '200325', '121411', '105967', '106000', '144645', '105273', '105819', '104467', '202385', '126952', '202462', '105497', '105707', '111797', '106148', '144895', '109054', '202130', '105015', '111761', '105550', '106328', '105732', '105585', '111190', '105299', '106432', '104947', '104607', '105467', '200483', '200711', '104919', '104882', '111578', '126205', '109739', '105062', '105074', '105064', '106296', '104022', '103819', '111574', '207176', '200175', '105155', '104925', '200619', '106329', '106078', '106045', '105499', '105156', '105526', '106220', '105747', '105656', '106044', '105633', '105936', '105589', '126535', '105842', '104547', '111577', '122548', '104797', '104897', '106281', '200615', '106324', '104308', '104656', '105163', '104792', '126652', '104597', '106391', '111581', '103970', '144707', '126207', '105916', '106026', '104629', '111456', '105023', '104620', '105373', '106075', '133297', '200514', '122330', '104978', '105208', '106298', '104660', '111459', '123768', '105641', '105683', '126845', '105583', '105223', '126774', '120424', '122669', '105085', '144817', '105561', '104926', '126102', '105051', '103781', '123921', '111200', '111511', '106106', '200045', '106043', '106109', '124116', '133975', '123795', '103852', '207836', '103990', '111805', '111460', '200095', '106186', '106138', '106412', '111515', '104593', '108763', '104297', '124022', '122236', '104233', '106283', '105441', '202090', '106361', '111202', '106105', '123755', '108739', '126340', '109698', '111192', '207738', '144826', '106058', '105643', '134114', '207972', '200005', '105147', '104571', '106423', '202358', '104291', '106174', '106121', '105430', '105827', '105952', '106177', '111513', '111575', '200611', '104180', '126094', '127339', '105166', '105807', '105477', '126125', '125802', '126204', '104745', '106250', '106415', '104259', '106396', '105217', '126203', '106228', '106210', '111815', '200484', '104678', '117356', '106421', '105902', '105932', '104731', '104468', '105613', '105379', '106005', '105030', '105815', '103333', '104312', '104907', '127143', '105226', '104898', '105948', '144750', '106099', '106401', '111790', '106333', '105436', '104871', '105812', '105657', '200250', '104534', '122078', '110602', '134120', '105870', '105992', '105985', '122109', '106167', '207479', '105487', '126530', '105554', '105676', '200574', '105691', '111153', '200274', '105357', '105376', '106120', '106065', '105063', '105138', '104890', '104122', '111576', '144719', '105479', '104970', '200218', '104755', '144776', '106325', '105502', '126174', '207139', '104999', '105882', '126610', '105111', '103917', '106393', '105757', '202382', '105943', '105077', '126846', '205734', '105332', '103565', '104527', '105577', '105961', '126523', '128034', '105173', '106398', '105432', '105614', '105311', '200000', '207400', '111442', '144760', '106071', '105626', '103898', '103893', '207971', '106368', '105575', '105933', '105453', '110536', '132482', '124187'}
# Postoji 419 različitih igrača
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points',
#        'id'],
#       dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt

data_reduced = data[['winner_id', 'winner_name', 'winner_ioc', 'loser_id', 'loser_name', 'loser_ioc', 'id']]

G = nx.Graph() # pravi praznu mrežu
G.add_nodes_from(skup_id) # dodaje čvorove čije su labele u "skup_id"

for _, winner_id, winner_name, winner_ioc, loser_id, loser_name, loser_ioc, _ in data_reduced.itertuples():
    winner_id_string = str(winner_id)
    loser_id_string = str(loser_id)
    if (winner_id_string, loser_id_string) in G.edges:
        G.edges[winner_id_string, loser_id_string]['weight'] += 1
    else:
        G.add_edge(winner_id_string, loser_id_string, weight=1)
        winner_attrs = {winner_id_string: {'name': winner_name, 'country': winner_ioc}}
        loser_attrs = {loser_id_string: {'name': loser_name, 'country': loser_ioc}}
        nx.set_node_attributes(G, winner_attrs)
        nx.set_node_attributes(G, loser_attrs)

# %%
print(data.dtypes)
print(G.edges.data("weight"))
print(nx.get_node_attributes(G, "name"))
print(nx.get_node_attributes(G, "country"))
output_path = "models/undirected_graph_2018.gml"

nx.write_gml(G, output_path)
# Out:
# tourney_id             object
# tourney_name           object
# surface                object
# draw_size               int64
# tourney_level          object
# tourney_date            int64
# match_num               int64
# winner_id               int64
# winner_seed           float64
# winner_entry           object
# winner_name            object
# winner_hand            object
# winner_ht             float64
# winner_ioc             object
# winner_age            float64
# loser_id                int64
# loser_seed            float64
# loser_entry            object
# loser_name             object
# loser_hand             object
# loser_ht              float64
# loser_ioc              object
# loser_age             float64
# score                  object
# best_of                 int64
# round                  object
# minutes               float64
# w_ace                 float64
# w_df                  float64
# w_svpt                float64
# w_1stIn               float64
# w_1stWon              float64
# w_2ndWon              float64
# w_SvGms               float64
# w_bpSaved             float64
# w_bpFaced             float64
# l_ace                 float64
# l_df                  float64
# l_svpt                float64
# l_1stIn               float64
# l_1stWon              float64
# l_2ndWon              float64
# l_SvGms               float64
# l_bpSaved             float64
# l_bpFaced             float64
# winner_rank           float64
# winner_rank_points    float64
# loser_rank            float64
# loser_rank_points     float64
# id                      int64
# dtype: object
# [('105899', '105656', 1), ('105899', '106175', 1), ('105899', '106412', 1), ('207421', '106397', 1), ('104198', '103852', 1), ('104198', '105332', 1), ('104198', '104607', 1), ('104198', '126094', 1), ('104198', '104122', 1), ('104198', '105807', 1), ('104198', '105643', 2), ('104198', '111797', 1), ('104198', '105589', 1), ('104198', '104926', 1), ('104198', '105815', 1), ('104198', '104269', 1), ('104198', '123921', 2), ('104198', '104755', 1), ('104198', '104312', 1), ('104198', '105216', 1), ('104198', '105453', 1), ('104198', '104745', 1), ('104198', '105992', 1), ('104198', '105173', 1), ('104198', '106233', 1), ('104198', '104527', 1), ('104198', '111575', 1), ('104198', '104871', 1), ('104198', '106121', 1), ('104198', '104898', 1), ('104198', '104792', 1), ('104198', '105671', 1), ('104198', '106421', 1), ('104198', '106148', 1), ('104198', '105583', 1), ('104198', '105916', 1), ('104198', '104571', 1), ('104198', '111202', 1), ('104198', '126610', 1), ('104198', '104678', 1), ('104198', '106045', 1), ('105960', '111577', 1), ('105539', '106233', 1), ('105539', '105173', 1), ('105539', '104252', 1), ('105539', '104926', 1), ('105539', '105041', 1), ('105539', '103607', 1), ('105539', '105453', 1), ('105539', '105985', 1), ('105539', '105385', 1), ('105539', '105449', 1), ('105539', '104882', 1), ('105539', '106000', 2), ('105539', '105936', 2), ('105539', '111575', 1), ('105539', '104731', 2), ('105539', '105379', 1), ('105539', '103970', 1), ('105539', '103781', 1), ('105539', '126774', 1), ('105539', '100644', 1), ('105539', '105526', 1), ('105539', '105015', 1), ('105539', '104755', 1), ('105539', '105575', 1), ('105539', '104259', 1), ('105539', '103893', 1), ('105539', '105477', 1), ('105539', '104291', 1), ('105539', '126094', 1), ('105539', '106421', 1), ('105539', '105373', 1), ('105539', '105051', 1), ('105539', '105062', 1), ('200031', '105683', 1), ('200460', '200045', 1), ('200460', '106397', 1), ('200460', '207139', 1), ('105413', '104297', 1), ('105413', '105807', 1), ('105413', '144895', 1), ('105413', '106148', 1), ('105413', '200000', 1), ('105341', '105932', 2), ('105341', '100644', 1), ('105341', '200000', 1), ('105341', '106000', 3), ('105341', '105936', 1), ('105341', '105614', 1), ('105341', '106058', 1), ('105341', '104755', 1), ('105341', '104312', 1), ('105341', '104022', 1), ('105341', '104871', 1), ('105341', '105051', 1), ('105341', '106432', 1), ('105341', '106026', 1), ('105341', '104527', 1), ('105341', '126774', 1), ('105341', '105626', 1), ('106378', '133430', 3), ('106378', '111202', 1), ('106378', '105777', 2), ('106378', '104731', 1), ('106378', '104797', 1), ('106378', '105932', 2), ('106378', '104312', 3), ('106378', '105227', 1), ('106378', '104534', 1), ('106378', '126207', 1), ('106378', '106210', 1), ('106378', '105430', 1), ('106378', '104291', 2), ('106378', '104755', 2), ('106378', '104665', 1), ('106378', '200282', 2), ('106378', '105311', 1), ('106378', '106421', 1), ('106378', '104925', 2), ('106378', '105676', 1), ('106378', '106298', 1), ('106378', '100644', 2), ('106378', '105916', 1), ('106378', '104926', 1), ('106378', '105992', 1), ('106378', '106401', 1), ('106378', '104918', 2), ('106378', '105062', 1), ('106378', '106109', 1), ('106378', '105614', 1), ('106378', '106043', 2), ('106378', '111456', 1), ('106378', '104919', 1), ('106378', '106148', 1), ('106378', '105449', 1), ('106378', '103893', 1), ('106378', '105376', 1), ('106378', '126610', 1), ('106378', '105583', 1), ('106378', '105936', 1), ('106378', '111797', 1), ('106378', '105077', 1), ('106378', '125802', 1), ('106378', '104792', 1), ('106378', '104269', 1), ('105065', '105376', 1), ('105065', '200615', 1), ('105065', '105077', 1), ('105065', '111513', 1), ('105065', '104259', 1), ('105065', '126203', 1), ('105065', '106044', 1), ('105065', '105051', 2), ('105065', '104871', 1), ('105065', '106216', 1), ('105065', '105359', 1), ('105065', '106368', 1), ('105065', '104999', 2), ('105065', '105575', 1), ...
# {'105899': 'Martin Cuevas', '207421': 'Alex Fairbanks', '104198': 'Guillermo Garcia Lopez', '105960': 'Evan King', '105539': 'Evgeny Donskoy', '200031': 'Lucas Catarina', '200460': 'John Bryan Decasa Otico', '105413': 'Andrej Martin', '105341': 'Thomas Fabbiano', '106378': 'Kyle Edmund', '105065': 'Tim Smyczek', '104655': 'Pablo Cuevas', '104665': 'Pablo Andujar', '106252': 'Joao Pedro Sorgi', '105385': 'Donald Young', '200282': 'Alex De Minaur', '134770': 'Casper Ruud', '106198': 'Hugo Dellien', '104545': 'John Isner', '200436': 'Zsombor Piros', '105227': 'Marin Cilic', '105359': 'Jason Jung', '104269': 'Fernando Verdasco', '126127': 'Benjamin Bonzi', '126120': 'Nino Serdarusic', '124079': 'Pedro Martinez', '133430': 'Denis Shapovalov', '104719': 'Marcel Granollers', '105238': 'Alexandr Dolgopolov', '200273': 'Hady Habib', '106233': 'Dominic Thiem', '111167': 'Ugo Nastasi', '105349': 'Harri Heliovaara', '100644': 'Alexander Zverev', '105515': 'Jordi Samper Montana', '106218': 'Marcos Giron', '106175': 'Ricardo Rodriguez', '106216': 'Bjorn Fratangelo', '106110': 'Filip Horansky', '105649': 'Cedrik Marcel Stebe', '111795': 'Filippo Baldi', '208029': 'Holger Rune', '144807': 'Kenneth Raisma', '103529': 'Aisam Ul Haq Qureshi', '106249': 'Joao Domingues', '207973': 'Ainius Sabaliauskas', '105041': 'Lukas Lacko', '200620': 'Ignacio Garcia', '105132': 'Jurgen Zopp', '104460': 'Dustin Brown', '206768': 'Rafael Eduardo Gonzalez Retana', '138846': 'Hong Kit Jack Wong', '124014': 'Ernesto Escobedo', '104542': 'Jo-Wilfried Tsonga', '200624': 'Sebastian Korda', '106232': 'Roberto Cid', '200401': 'Amir Hossein Badi', '103499': 'Aqeel Khan', '106348': 'Evgeny Karlovskiy', '104586': 'Lukas Rosol', '105587': 'Tom Kocevar Desman', '105449': 'Steve Johnson', '126526': 'Soren Hess Olesen', '106214': 'Oscar Otte', '105566': 'Shahin Khaledan', '206642': 'Yassir Kilani', '105806': 'Mirza Basic', '208028': 'Francisco Llanes', '104810': 'Zhe Li', '206000': 'Michel Saade', '104252': 'Florian Mayer', '104918': 'Andy Murray', '111794': 'Kamil Majchrzak', '105634': 'Viktor Galovic', '104932': 'Kenny De Schepper', '138845': 'Anthony Jackie Tang', '136440': 'Dominik Koepfer', '106072': 'Alexey Vatutin', '103607': 'Victor Estrella', '105053': 'Santiago Giraldo', '106397': 'Wishaya Trongcharoenchaikul', '138431': 'Darko Bojanovic', '104672': 'Vincent Millot', '200384': 'Hugo Gaston', '127300': 'Jurabek Karimov', '104494': 'Adrian Ungur', '104563': 'Luca Vanni', '126190': 'Nicolas Alvarez', '105216': 'Yuichi Sugita', '106150': 'Jeson Patrombon', '111197': 'Jonathan Mridha', '105777': 'Grigor Dimitrov', '105671': 'Gastao Elias', '134868': 'Tallon Griekspoor', '124126': 'Sarp Agabigun', '200059': 'Yibing Wu', '105493': 'Tomislav Brkic', '106426': 'Christian Garin', '200278': 'Simon Carr', '106410': 'Jorge Brian Panta Herreros', '132283': 'Lorenzo Sonego', '200325': 'Emil Ruusuvuori', '105606': 'Mohsen Hossein Zade', '121411': 'Moez Chargui', '105967': 'Henri Laaksonen', '106000': 'Damir Dzumhur', '144645': 'Zdenek Kolar', '105273': 'Mauricio Echazu', '105819': 'Guido Andreozzi', '104467': 'Lamine Ouahab', '202385': 'Jenson Brooksby', '126952': 'Soon Woo Kwon', '105497': 'Jose Hernandez', '202462': 'Yasitha De Silva', '105707': 'Nicolaas Scholtz', '111797': 'Nicolas Jarry', '106148': 'Roberto Carballes Baena', '144895': 'Corentin Moutet', '109054': 'Daniel Masur', '202130': 'Emil Reinberg', '105015': 'Franko Skugor', '111761': 'Benjamin Lock', '105550': 'Guido Pella', '106328': 'Christian Harrison', '105732': 'Pierre Hugues Herbert', '105585': 'Ze Zhang', '111190': 'Zhizhen Zhang', '105299': 'Dzmitry Zhyrmont', '106432': 'Borna Coric', '104947': 'Marsel Ilhan', '104607': 'Tomas Berdych', '105467': 'Jordi Munoz Abreu', '200483': 'Peter August Anker', '200711': 'Nicolas Mejia', '104919': 'Leonardo Mayer', '104882': 'Blaz Kavcic', '126205': 'Tommy Paul', '111578': 'Stefan Kozlov', '109739': 'Maximilian Marterer', '105062': 'Mikhail Kukushkin', '105074': 'Ruben Beme ...
# {'105899': 'URU', '207421': 'SRI', '104198': 'ESP', '105960': 'USA', '105539': 'RUS', '200031': 'MON', '200460': 'PHI', '105413': 'SVK', '105341': 'ITA', '106378': 'GBR', '105065': 'USA', '104655': 'URU', '104665': 'ESP', '106252': 'BRA', '105385': 'USA', '200282': 'AUS', '134770': 'NOR', '106198': 'BOL', '104545': 'USA', '200436': 'HUN', '105227': 'CRO', '105359': 'TPE', '104269': 'ESP', '126127': 'FRA', '126120': 'CRO', '124079': 'ESP', '133430': 'CAN', '104719': 'ESP', '105238': 'UKR', '200273': 'LIB', '106233': 'AUT', '111167': 'LUX', '105349': 'FIN', '100644': 'GER', '105515': 'ESP', '106218': 'USA', '106175': 'VEN', '106216': 'USA', '106110': 'SVK', '105649': 'GER', '111795': 'ITA', '208029': 'DEN', '144807': 'EST', '103529': 'PAK', '106249': 'POR', '207973': 'LTU', '105041': 'SVK', '200620': 'PUR', '105132': 'EST', '104460': 'GER', '206768': 'ESA', '138846': 'HKG', '124014': 'USA', '104542': 'FRA', '200624': 'USA', '106232': 'DOM', '200401': 'IRI', '103499': 'PAK', '106348': 'RUS', '104586': 'CZE', '105587': 'SLO', '105449': 'USA', '126526': 'DEN', '106214': 'GER', '105566': 'IRI', '206642': 'MAR', '105806': 'BIH', '208028': 'URU', '104810': 'CHN', '206000': 'LIB', '104252': 'GER', '104918': 'GBR', '111794': 'POL', '105634': 'ITA', '104932': 'FRA', '138845': 'HKG', '136440': 'GER', '106072': 'RUS', '103607': 'DOM', '105053': 'COL', '106397': 'THA', '138431': 'BIH', '104672': 'FRA', '200384': 'FRA', '127300': 'UZB', '104494': 'ROU', '104563': 'ITA', '126190': 'PER', '105216': 'JPN', '106150': 'PHI', '111197': 'SWE', '105777': 'BUL', '105671': 'POR', '134868': 'NED', '124126': 'TUR', '200059': 'CHN', '105493': 'BIH', '106426': 'CHI', '200278': 'IRL', '106410': 'PER', '132283': 'ITA', '200325': 'FIN', '105606': 'IRI', '121411': 'TUN', '105967': 'SUI', '106000': 'BIH', '144645': 'CZE', '105273': 'PER', '105819': 'ARG', '104467': 'ALG', '202385': 'USA', '126952': 'KOR', '105497': 'DOM', '202462': 'SRI', '105707': 'RSA', '111797': 'CHI', '106148': 'ESP', '144895': 'FRA', '109054': 'GER', '202130': 'USA', '105015': 'CRO', '111761': 'ZIM', '105550': 'ARG', '106328': 'USA', '105732': 'FRA', '105585': 'CHN', '111190': 'CHN', '105299': 'BLR', '106432': 'CRO', '104947': 'TUR', '104607': 'CZE', '105467': 'VEN', '200483': 'NOR', '200711': 'COL', '104919': 'ARG', '104882': 'SLO', '126205': 'USA', '111578': 'USA', '109739': 'GER', '105062': 'KAZ', '105074': 'BEL', '105064': 'BRA', '106296': 'FRA', '104022': 'RUS', '103819': 'SUI', '111574': 'USA', '105155': 'POR', '207176': 'INA', '200175': 'SRB', '104925': 'SRB', '200619': 'PUR', '106329': 'BRA', '106078': 'BLR', '106045': 'USA', '105499': 'GUA', '134886': 'SRI', '105747': 'EGY', '105526': 'GER', '105156': 'BOL', '106220': 'BUL', '105656': 'ESA', '106044': 'ARG', '105633': 'EGY', '105589': 'AUT', '105936': 'SRB', '126535': 'ESP', '105842': 'CHN', '104547': 'ARG', '111577': 'USA', '122548': 'ISR', '104797': 'UZB', '106281': 'GBR', '104897': 'GER', '200615': 'AUS', '106324': 'CZE', '104308': 'POL', '104656': 'BAR', '105163': 'FRA', '104792': 'FRA', '106353': 'SRB', '126652': 'GBR', '104597': 'ESP', '106391': 'SUI', '111581': 'USA', '103970': 'ESP', '144707': 'SWE', '126207': 'USA', '105916': 'HUN', '106026': 'IND', '104629': 'ESP', '111456': 'USA', '105023': 'USA', '104620': 'ITA', '105373': 'SVK', '106075': 'SVK', '126939': 'UZB', '133297': 'JPN', '200514': 'AUT', '122330': 'KAZ', '134217': 'HKG', '127570': 'URU', '105935': 'PER', '104251': 'TPE', '104978': 'GER', '202165': 'PHI', '105208': 'LAT', '106298': 'FRA', '104660': 'UKR', '111459': 'IND', '123768': 'USA', '105641': 'SLO', '105683': 'CAN', '126845': 'AUS', '105583': 'SRB', '105223': 'ARG', '126774': 'GRE', '120424': 'GER', '122669': 'PER', '105085': 'UKR', '144817': 'SUI', '105561': 'ITA', '104926': 'ITA', '126102': 'ROU', '105051': 'AUS', '120792': 'PAK', '103781': 'AUT', '123921': 'FRA', '111200': 'SWE', '111511': 'USA', '106106': 'GEO', '200045': 'INA', '106043': 'ARG', '106109': 'AUS', '124116': 'AUT', '133975': 'GER', '202 ...

# %% [markdown]
# 1.pitanje Koliki je prosecan broj tenisera(saigraca) po svakom teniseru?
# gephi->ucitala graf, Statistics -> Network Overview -> Average Degree
#
# <img src="img/1.pitanje_average_degree" width=500 height=500 />

# %%
#2.pitanje Koji teniseri su se susretali sa najvecim brojem drugih tenisera
my_degrees = dict(G.degree()) #dictionary key:value
degree_values = [v for k, v in G.degree()]

print(max(my_degrees.items(), key= lambda x: x[1])) #max u tom dict 

print(nx.get_node_attributes(G, 'name')['104926']) #atribut name za cvor ciji je index rezultat prethodnog upita
# Out:
# ('104926', 61)
# Fabio Fognini

# %%
#3.pitanje Koji teniseri su ucestvovali na najvecem broju (razlicih) turnira?
winner_tourney_columns = ['winner_id', 'tourney_id']
loser_tourney_columns = ['loser_id', 'tourney_id']
dataWinner_tourney = data[winner_tourney_columns].drop_duplicates().groupby('winner_id').count()
print(dataWinner_tourney)
dataLoser_tourney = data[loser_tourney_columns].drop_duplicates().groupby('loser_id').count()
print(dataLoser_tourney)

print(nx.get_node_attributes(G, 'name')['100644'])
print(nx.get_node_attributes(G, 'name')['103333'])

#check???
# Out:
#            tourney_id
# winner_id
# 100644             20
# 103333              7
# 103499              2
# 103529              1
# 103565              1
# ...               ...
# 202358              1
# 207139              1
# 207415              1
# 208028              1
# 208029              1
#
# [282 rows x 1 columns]
#           tourney_id
# loser_id
# 100644            19
# 103333            16
# 103499             1
# 103529             1
# 103565             2
# ...              ...
# 207738             1
# 207836             1
# 207971             1
# 207972             1
# 207973             1
#
# [393 rows x 1 columns]
# Alexander Zverev
# Ivo Karlovic

# %%
#4.pitanje Koji teniseri su dobri kandidati za predstavnike profesionalnih tenisera? Da li se i sta se menja ukoliko se umesto jednog bira skup od nekoliko predstavnika? Dobar predstavnik ili predstavnici bi trebalo da budu u kontaktu sa sto vecim skupom tenisera

#proveriti ovaj 2.deo na sta se odnosi????
#mere centralnosti koristim Degree centrality, vise u kontaktu sa drugim teniserima teze da budu predstavnici
import operator
dictionary = dict(nx.degree_centrality(G))
print(sorted(dictionary.items(), key=operator.itemgetter(1), reverse=True)[:5])
# Out:
# [('104926', 0.14593301435406697), ('106233', 0.13157894736842105), ('126774', 0.12679425837320574), ('100644', 0.12440191387559808), ('104755', 0.12200956937799043)]

# %%
print(nx.get_node_attributes(G, 'name')['104926'])
print(nx.get_node_attributes(G, 'name')['106233'])
print(nx.get_node_attributes(G, 'name')['126774'])
print(nx.get_node_attributes(G, 'name')['100644'])
print(nx.get_node_attributes(G, 'name')['104755'])
# Out:
# Fabio Fognini
# Dominic Thiem
# Stefanos Tsitsipas
# Alexander Zverev
# Richard Gasquet

# %% [markdown]
# Prvo kreiramo masku koja ce da selektuje sve igrace koji su u skupu igraca koji su igrali mec u 2018
# Potom dobijen rezultat grupisemo po drzavi i sortiramo zatim
# Najaktivniji su iz SAD, Francuske, Spanije, Nemacke, Italije
# Srbija na 9 mestu sa Rusijom i Kanadom sa 7 aktivnih igraca

# %%
maska_active_players = players_data['player_id'].isin(skup_id) 
active_players_2018 = players_data[maska_active_players]
data_grupisano = active_players_2018[['player_id', 'country_code']].groupby('country_code')
data_agregirano = data_grupisano['country_code'].agg(np.size)

print(data_agregirano.sort_values(ascending=False).head(20))
# Out:
# country_code
# USA    34
# FRA    25
# ESP    24
# GER    18
# ITA    17
# ARG    15
# AUS    14
# AUT     8
# RUS     7
# CAN     7
# SRB     7
# GBR     6
# CZE     6
# CRO     6
# ROU     6
# SVK     6
# SUI     6
# BRA     6
# TPE     6
# IND     6
# Name: country_code, dtype: int64
